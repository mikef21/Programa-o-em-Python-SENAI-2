# %% [markdown]
# <a href="https://colab.research.google.com/github/mikef21/Programa-o-em-Python-SENAI-2/blob/main/Aula_8_16_mar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # FUNÇÕES EM PYTHON
#
# UTILIZADAS PARA ECONOMIZAR TEMPO E ESFORÇO

# %% [markdown]
# ## SINTAXE

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Exemplo de função sem parâmetro

def dizer_ola():
    print("Olá Senai M353!")

dizer_ola()
# Out:
# Olá Senai M353!

# %%
# Exemplo de função com parâmetro

def repetir_ola(x):
    for i in range(x):
        print("Olá Senai M353!")

repetir_ola(5)
# Out:
# Olá Senai M353!
# Olá Senai M353!
# Olá Senai M353!
# Olá Senai M353!
# Olá Senai M353!
